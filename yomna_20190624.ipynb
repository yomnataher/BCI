# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t = [0 , 30 , 45 , 60 , 90 ]
#sin(0) & cos(0)
#sin(30) & cos(30)
#sin(45) & cos(45)
#sin(60) & cos(60)
#sin(90) & cos(90)

# %%
x = [i*(np.pi/180) for i in t ]

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(t,np.sin(x) , marker = "*" , label = "sin")
plt.plot(t,np.cos(x) , marker = "+" , label = "cos")
plt.xticks(t)
# Out:
# ([<matplotlib.axis.XTick at 0x7fc7361b0f90>,
#   <matplotlib.axis.XTick at 0x7fc7361c4dd0>,
#   <matplotlib.axis.XTick at 0x7fc73c29c210>,
#   <matplotlib.axis.XTick at 0x7fc735d20850>,
#   <matplotlib.axis.XTick at 0x7fc735d20dd0>],
#  <a list of 5 Text major ticklabel objects>)

# %%
t = np.linspace(-np.pi , np.pi)
plt.plot(t,np.sin(t) , marker = "*" , label = "sin")
plt.plot(t,np.cos(t) , marker = "+" , label = "cos")

# %%
t = np.arange(0 , 4*np.pi , 0.5)
plt.plot(t,np.sin(t) , marker = "*" , label = "sin")
plt.plot(t,np.cos(t) , marker = "+" , label = "cos")

# %%
t = np.arange(0 , 2*np.pi , 0.5)
plt.plot(t,np.sin(t) , marker = "*" , label = "sin")
plt.plot(t,np.cos(t) , marker = "+" , label = "cos")

# %%
t = np.arange(0 , 6*np.pi , 0.5)
plt.plot(t,np.sin(t) , marker = "*" , label = "sin")
plt.plot(t,np.cos(t) , marker = "+" , label = "cos")

# %%
t = np.arange(0 , 4*np.pi-1 , 0.2)
plt.plot(t,np.sin(t) , marker = "*" , label = "sin")
plt.plot(t,np.cos(t) , marker = "+" , label = "cos")

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from pylab import rcParams
rcParams['figure.figsize'] = 16, 9

fig, ax = plt.subplots(1,1)
plt.axis('equal')

ax.set_xlim([0, 2*np.pi])
ax.set_ylim([-2.5, 2.5])

# sine function plot
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

# x axis path
ax.plot(3*x - 3, 0*y, linewidth=1, color='#dddddd')
# y axis path
ax.plot(0*x, 2.5*y, linewidth=1, color='#dddddd')

# unit circle path
ax.plot(np.cos(x), np.sin(x), linewidth=1)
# sine path
ax.plot(x + 1, np.sin(x), linewidth=1)


# ------ anim -------
sineLine, = ax.plot([], [], linewidth=4)
sineDot, = ax.plot([], [], 'o', color='#ff0000')

circleLine, = ax.plot([], [],linewidth=4)
circleDot, = ax.plot([], [], 'o', color='black')

def sineAnim(i):
    # sine anim
    sineLine.set_data(x[:i] + 1,y[:i])
    sineDot.set_data(x[i] + 1, y[i])
    # circle anim
    circleLine.set_data(np.cos(x[:i]), np.sin(x[:i]))
    circleDot.set_data(np.cos(x[i]), np.sin(x[i]))

anim = animation.FuncAnimation(fig, sineAnim, frames=len(x), interval=50)
# -------------

anim.save('sine-py-effect.mp4', writer='ffmpeg')

# plt.show()
# HTML(anim.to_html5_video())
